# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline

# %%
songs_playlist_df = pd.read_csv('/Users/nitanshjain/Documents/Data_Science_Learning/Spotify_Recommender_System/csv/songs_playlist_df.csv')
songs_50_df = pd.read_csv('/Users/nitanshjain/Documents/Data_Science_Learning/Spotify_Recommender_System/csv/songs_50_df.csv')

# %%
songs_playlist_df.drop(columns="album", axis=1, inplace=True)

# %%
songs_playlist_df.head()
# Out:
#                                track_name    artist_name  artist_pop  \
# 0                               You Right       Doja Cat          88
# 1               Wild Side (feat. Cardi B)        Normani          68
# 2  Peaches (feat. Daniel Caesar & Giveon)  Justin Bieber          90
# 3                      Chicken Lemon Rice     Priya Ragu          42
# 4        LALA (Unlocked) (feat. Swae Lee)    Alicia Keys          76
#
#                                        artist_genres  danceability  energy  \
# 0                               ['dance pop', 'pop']         0.828   0.621
# 1  ['dance pop', 'pop', 'post-teen pop', 'r&b', '...         0.740   0.576
# 2                            ['canadian pop', 'pop']         0.677   0.696
# 3                                   ['zurich indie']         0.516   0.895
# 4  ['hip pop', 'neo soul', 'pop', 'r&b', 'urban c...         0.615   0.560
#
#    loudness  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0    -6.414       0.0565      0.016400          0.002330    0.0845    0.436
# 1    -6.744       0.1460      0.024900          0.000000    0.1040    0.315
# 2    -6.181       0.1190      0.321000          0.000000    0.4200    0.464
# 3    -5.770       0.0919      0.000376          0.540000    0.4920    0.694
# 4    -4.938       0.1840      0.088900          0.000114    0.3140    0.330
#
#      tempo  duration_ms  time_signature  genre_score  track_pop
# 0  128.986       186173               4          819         85
# 1  110.095       209476               4         1166          7
# 2   90.030       198082               4          574         87
# 3  199.923       153019               4            3         38
# 4  139.441       266937               4          651         48

# %%
songs_50_df.head()
# Out:
#                                    track_name      artist_name  artist_pop  \
# 0  Cheerleader - Felix Jaehn Remix Radio Edit              OMI          64
# 1        Here Comes The Sun - Remastered 2009      The Beatles          82
# 2                                     Shallow        Lady Gaga          83
# 3                            Sweet but Psycho          Ava Max          80
# 4                               Tacones Rojos  Sebastian Yatra          80
#
#                                        artist_genres  danceability  energy  \
# 0                                      ['dance pop']         0.782   0.685
# 1  ['beatlesque', 'british invasion', 'classic ro...         0.557   0.540
# 2                    ['art pop', 'dance pop', 'pop']         0.572   0.385
# 3                               ['dance pop', 'pop']         0.720   0.706
# 4  ['colombian pop', 'latin', 'reggaeton colombia...         0.748   0.856
#
#    loudness  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0    -6.237       0.0309        0.1660          0.000012     0.160    0.603
# 1   -10.484       0.0347        0.0339          0.002480     0.179    0.394
# 2    -6.362       0.0308        0.3710          0.000000     0.231    0.323
# 3    -4.719       0.0473        0.0684          0.000000     0.166    0.620
# 4    -3.517       0.0348        0.0824          0.000000     0.142    0.927
#
#      tempo  duration_ms  time_signature  genre_score  track_pop
# 0  118.016       180566               4         13.0         79
# 1  129.171       185733               4         15.0         82
# 2   95.799       215733               4         34.0         83
# 3  133.002       187436               4         32.0         81
# 4  123.031       189320               4         14.0         84

# %%
songs_playlist_df.drop(columns=["artist_genres","time_signature","artist_name"], axis=1, inplace=True)
songs_50_df.drop(columns=["artist_genres","time_signature","artist_name"], axis=1, inplace=True)

# %%
songs_playlist_np = songs_playlist_df.copy()
songs_playlist_np.drop("track_name", axis=1, inplace=True)
songs_playlist_np = songs_playlist_np.to_numpy()

songs_50_np = songs_50_df.copy()
songs_50_np.drop("track_name", axis=1, inplace=True)
songs_50_np = songs_50_np.to_numpy()

# %%
from sklearn.metrics.pairwise import linear_kernel
cosine_sim_playlist = linear_kernel(songs_playlist_np, songs_playlist_np)
cosine_sim_50 = linear_kernel(songs_50_np, songs_50_np)

# %%
print(cosine_sim_playlist.shape)
print(cosine_sim_50.shape)
# Out:
# (2164, 2164)
# (44, 44)

# %%
songs_playlist_indices = pd.Series(songs_playlist_df.index, index=songs_playlist_df["track_name"]).drop_duplicates()
songs_50_indices = pd.Series(songs_50_df.index, index=songs_50_df["track_name"]).drop_duplicates()

# %%
def get_recommendations(title, cosine_sim_playlist=cosine_sim_playlist):
    index = songs_playlist_indices[title]
    sim_scores = list(enumerate(cosine_sim_playlist[index]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]
    recommended_songs_indices = [i[0] for i in sim_scores]
    return songs_playlist_df["track_name"].iloc[recommended_songs_indices]

# %%
# Out:
# 712     The Raven Child (feat. Hansi Kürsch & Jorn Lande)
# 2054                                   Bhar Do Jholi Meri
# 1360                                              Mirrors
# 1783                               Kabhi Alvida Naa Kehna
# 962                        Seymour Reads the Constitution
# 1804                                             Kajra Re
# 1785        Dil Ne Dil Ko Pukara-Babul Supriyo And Chorus
# 1985                                               Madari
# 1004                                        I Should Care
# 1741                                    Yun Hi Chala Chal
# Name: track_name, dtype: object

# %% [markdown]
# ```https://towardsdatascience.com/a-one-stop-shop-for-principal-component-analysis-5582fb7e0a9c```
# ```https://www.datacamp.com/tutorial/recommender-systems-python```
