# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline

# %% [markdown]
# <p>Creating dataframes from following csv files</p>

# %%
songs_playlist_df = pd.read_csv('/Users/nitanshjain/Documents/Data_Science_Learning/Spotify_Recommender_System/csv/songs_playlist_df.csv')
songs_50_df = pd.read_csv('/Users/nitanshjain/Documents/Data_Science_Learning/Spotify_Recommender_System/csv/songs_50_df.csv')

# %%
# dropping columns
songs_playlist_df.drop(columns=["album", "artist_genres","time_signature","artist_name"], axis=1, inplace=True) 
songs_50_df.drop(columns=["artist_genres","time_signature","artist_name"], axis=1, inplace=True)

# %%
songs_playlist_df.drop_duplicates(subset='track_name', inplace=True) # removing duplicate songs based on track name
songs_50_df.drop_duplicates(subset='track_name', inplace=True)

# %%
songs_playlist_df.head()
# Out:
#                                track_name  artist_pop  danceability  energy  \
# 0                               You Right          88         0.828   0.621
# 1               Wild Side (feat. Cardi B)          68         0.740   0.576
# 2  Peaches (feat. Daniel Caesar & Giveon)          90         0.677   0.696
# 3                      Chicken Lemon Rice          42         0.516   0.895
# 4        LALA (Unlocked) (feat. Swae Lee)          76         0.615   0.560
#
#    loudness  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0    -6.414       0.0565      0.016400          0.002330    0.0845    0.436
# 1    -6.744       0.1460      0.024900          0.000000    0.1040    0.315
# 2    -6.181       0.1190      0.321000          0.000000    0.4200    0.464
# 3    -5.770       0.0919      0.000376          0.540000    0.4920    0.694
# 4    -4.938       0.1840      0.088900          0.000114    0.3140    0.330
#
#      tempo  duration_ms  genre_score  track_pop
# 0  128.986       186173        860.0         85
# 1  110.095       209476       1227.0          7
# 2   90.030       198082        597.0         87
# 3  199.923       153019          3.0         38
# 4  139.441       266937        669.0         48

# %%
songs_50_df.head()
# Out:
#                                    track_name  artist_pop  danceability  \
# 0  Cheerleader - Felix Jaehn Remix Radio Edit          64         0.782
# 1        Here Comes The Sun - Remastered 2009          82         0.557
# 2                                     Shallow          83         0.572
# 3                            Sweet but Psycho          80         0.720
# 4                               Tacones Rojos          80         0.748
#
#    energy  loudness  speechiness  acousticness  instrumentalness  liveness  \
# 0   0.685    -6.237       0.0309        0.1660          0.000012     0.160
# 1   0.540   -10.484       0.0347        0.0339          0.002480     0.179
# 2   0.385    -6.362       0.0308        0.3710          0.000000     0.231
# 3   0.706    -4.719       0.0473        0.0684          0.000000     0.166
# 4   0.856    -3.517       0.0348        0.0824          0.000000     0.142
#
#    valence    tempo  duration_ms  genre_score  track_pop
# 0    0.603  118.016       180566         13.0         79
# 1    0.394  129.171       185733         15.0         82
# 2    0.323   95.799       215733         34.0         83
# 3    0.620  133.002       187436         32.0         81
# 4    0.927  123.031       189320         14.0         84

# %% [markdown]
# <p>Scaling the data using Standard Scaler</p>

# %%
from sklearn import preprocessing
scaler = preprocessing.StandardScaler()
songs_playlist_df.loc[:,"artist_pop":"track_pop"] = scaler.fit_transform(songs_playlist_df.loc[:,"artist_pop":"track_pop"])
songs_50_df.loc[:,"artist_pop":"track_pop"] = scaler.fit_transform(songs_50_df.loc[:,"artist_pop":"track_pop"])

# %%
songs_playlist_np = songs_playlist_df.copy()
songs_playlist_np.drop("track_name", axis=1, inplace=True)
songs_playlist_np = songs_playlist_np.to_numpy()

songs_50_np = songs_50_df.copy()
songs_50_np.drop("track_name", axis=1, inplace=True)
songs_50_np = songs_50_np.to_numpy()

# %%
from sklearn.metrics.pairwise import linear_kernel
cosine_sim_playlist = linear_kernel(songs_playlist_np, songs_playlist_np)
cosine_sim_50 = linear_kernel(songs_50_np, songs_50_np)

# %%
print(cosine_sim_playlist.shape)
print(cosine_sim_50.shape)
# Out:
# (2165, 2165)
# (44, 44)

# %%
songs_playlist_indices = pd.Series(songs_playlist_df.index, index=songs_playlist_df["track_name"]).drop_duplicates()
songs_50_indices = pd.Series(songs_50_df.index, index=songs_50_df["track_name"]).drop_duplicates()

# %%
def get_recommendations(title):
    
    index = songs_playlist_indices[title]
    # print(index)
    # print(cosine_sim_playlist[index])
    sim_scores = list(enumerate(cosine_sim_playlist[index]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    sim_scores = sim_scores[1:11]
    # print(sim_scores)
    
    recommended_songs_indices = [i[0] for i in sim_scores]
    return songs_playlist_df["track_name"].iloc[recommended_songs_indices]

# %%
for song in songs_50_df.track_name:
    print("The following songs were recommended for \n{}".format(song))
    try:
        print(get_recommendations(song))
    except:
        print("\n")
# Out:
# The following songs were recommended for
# Cheerleader - Felix Jaehn Remix Radio Edit
# 1157                                      Me Porto Bonito
# 2024                                        Tacones Rojos
# 1167                              Cold Heart - PNAU Remix
# 187                                                 Woman
# 1298                      There's Nothing Holdin' Me Back
# 136                                       Clap Your Hands
# 267     Bhool Bhulaiyaa 2 Title Track (From "Bhool Bhu...
# 205                                                  Numb
# 1323                                               Sucker
# 2083                                            Moonlight
# Name: track_name, dtype: object
# The following songs were recommended for
# Here Comes The Sun - Remastered 2009
#
#
# The following songs were recommended for
# Shallow
# 1418       Lonely (with benny blanco)
# 1866    Best Part of Me (feat. YEBBA)
# 1446                          Falling
# 1897           exile (feat. Bon Iver)
# 2025                          Shallow
# 1858                    It'll Be Okay
# 1869                          traitor
# 1829              I GUESS I'M IN LOVE
# 1425            when the party's over
# 474     Lean On (feat. MØ & DJ Snake)
# Name: track_name, dtype: object
# The following songs were recommended for
# Sweet but Psycho
# 1973                  You for Me
# 1169    One Kiss (with Dua Lipa)
# 187                        Woman
# 205                         Numb
# 1323                      Sucker
# 1428                   The Motto
# 224              I Ain't Worried
# 1383                    Physical
# 1376             Don't Start Now
# 1909                    Sunshine
# Name: track_name, dtype: object
# The following songs were recommended for
# Tacones Rojos
# 1167                              Cold Heart - PNAU Remix
# 244                                            SUPERMODEL
# 1298                      There's Nothing Holdin' Me Back
# 2030                     La Gozadera (feat. Marc Anthony)
# 1173                                Una Noche en Medellín
# 165                                    Late Night Talking
# 267     Bhool Bhulaiyaa 2 Title Track (From "Bhool Bhu...
# 1175                                              Shivers
# 187                                                 Woman
# 1318                                                 Rude
# Name: track_name, dtype: object
# The following songs were recommended for
# Me Voy Enamorando
# 670                                   Midnight Sun
# 665                          Welcome To The Circus
# 725                              Bloodheads United
# 2113                                 My Lighthouse
# 1445                        Call on Me - Radio Mix
# 1165                                         Tarot
# 271     The Punjaabban Song (From "Jugjugg Jeeyo")
# 1237                    We're All In This Together
# 1241                                           I2I
# 2139                               Queen of Hearts
# Name: track_name, dtype: object
# The following songs were recommended for
# Bailando - Spanish Version
# 267     Bhool Bhulaiyaa 2 Title Track (From "Bhool Bhu...
# 200                                            Levitating
# 1426                                              Lullaby
# 1798                                      Bhool Bhulaiyaa
# 291                        Chaka Chak (From "Atrangi Re")
# 1527                       Uptown Funk (feat. Bruno Mars)
# 65                                           Lonely Heart
# 1412                                         Say It Right
# 1602    Valerie (feat. Amy Winehouse) - Version Revisited
# 187                                                 Woman
# Name: track_name, dtype: object
# The following songs were recommended for
# Somebody That I Used To Know (Glee Cast Version)
# 763                                       Where You Lead
# 2021    Somebody That I Used To Know (Glee Cast Version)
# 555                                           Samfie Man
# 1356                        Somebody That I Used To Know
# 554                                 It Must Be True Love
# 892                                          Hummingbird
# 2083                                           Moonlight
# 557                           First Time for a Long Time
# 537                                            Cry To Me
# 2147                                           Hot Stuff
# Name: track_name, dtype: object
# The following songs were recommended for
# All of the Stars
# 1429    What Goes Around.../...Comes Around (Interlude)
# 474                       Lean On (feat. MØ & DJ Snake)
# 2058                                  Louder Than Words
# 1639                                   All of the Stars
# 13                           Leave The Door Open - Live
# 1165                                              Tarot
# 670                                        Midnight Sun
# 89                          If We’ll Ever Be Remembered
# 1592                       She Will Be Loved - Acoustic
# 1834                                  Run Through Walls
# Name: track_name, dtype: object
# The following songs were recommended for
# Cups (Pitch Perfect’s “When I’m Gone”) - Pop Version
# 214                                                Grrrls
# 2122    Cups (Pitch Perfect’s “When I’m Gone”) - Pop V...
# 376                                             bleachers
# 161                                         Jiggle Jiggle
# 538                               Let the Power Fall On I
# 1970                        Ice Cream (with Selena Gomez)
# 2037                                            Boho Days
# 1173                                Una Noche en Medellín
# 1186                                        Nobody Like U
# 557                            First Time for a Long Time
# Name: track_name, dtype: object
# The following songs were recommended for
# Happier
# 181                            Bam Bam (feat. Ed Sheeran)
# 65                                           Lonely Heart
# 64                    Potion (with Dua Lipa & Young Thug)
# 1169                             One Kiss (with Dua Lipa)
# 187                                                 Woman
# 1379                                               My Way
# 1420          Light It Up (feat. Nyla & Fuse ODG) [Remix]
# 1530                                                 2002
# 1317                                              Happier
# 267     Bhool Bhulaiyaa 2 Title Track (From "Bhool Bhu...
# Name: track_name, dtype: object
# The following songs were recommended for
# Boho Days
# 1133                           Judge
# 1382                    Ready or Not
# 1349                   Love Yourself
# 1854          Hey Stupid, I Love You
# 547     Botheration - Reggae Version
# 1320                      Youngblood
# 258                            MEAN!
# 1113     Rule Over (Putt Jattan Dey)
# 1147                     Gustakhiyan
# 217                               14
# Name: track_name, dtype: object
# The following songs were recommended for
# Broken Frame
# 2027                 Broken Frame
# 1729                          Maa
# 1786                     Ik Onkar
# 1027                        Misty
# 1597                         Heal
# 939     Going Where the Lonely Go
# 1253              Go the Distance
# 1016              A Time for Love
# 1820              If You Love Her
# 1425        when the party's over
# Name: track_name, dtype: object
# The following songs were recommended for
# Je T'aime
# 1357           Shout Out to My Ex
# 2015                  Black Magic
# 1426                      Lullaby
# 1464                        Rihaa
# 1694      Better When I'm Dancin'
# 65                   Lonely Heart
# 1778    Kaho Naa Pyar Hai - Happy
# 1516                The Lazy Song
# 791          Bad, Bad Leroy Brown
# 52                  BREAK MY SOUL
# Name: track_name, dtype: object
# The following songs were recommended for
# Let My Love Open The Door
#
#
# The following songs were recommended for
# Bad Habits
# 271     The Punjaabban Song (From "Jugjugg Jeeyo")
# 1218                          Colombia, Mi Encanto
# 1533                                    Bad Habits
# 13                      Leave The Door Open - Live
# 474                  Lean On (feat. MØ & DJ Snake)
# 1403                                     Rescue Me
# 1756                             Deewangi Deewangi
# 1436                              When You're Gone
# 1816                                 Nagada Nagada
# 156                                About Damn Time
# Name: track_name, dtype: object
# The following songs were recommended for
# I Hear a Symphony
#
#
# The following songs were recommended for
# Billionaire (feat. Bruno Mars)
# 1854          Hey Stupid, I Love You
# 1382                    Ready or Not
# 1133                           Judge
# 1349                   Love Yourself
# 1320                      Youngblood
# 1147                     Gustakhiyan
# 217                               14
# 547     Botheration - Reggae Version
# 1293                Treat You Better
# 1445          Call on Me - Radio Mix
# Name: track_name, dtype: object
# The following songs were recommended for
# Line By Line (feat. Maren Morris)
#
#
# The following songs were recommended for
# Dynamite
# 267     Bhool Bhulaiyaa 2 Title Track (From "Bhool Bhu...
# 1323                                               Sucker
# 187                                                 Woman
# 1169                             One Kiss (with Dua Lipa)
# 1412                                         Say It Right
# 1175                                              Shivers
# 1287                             What Makes You Beautiful
# 1426                                              Lullaby
# 1527                       Uptown Funk (feat. Bruno Mars)
# 1973                                           You for Me
# Name: track_name, dtype: object
# The following songs were recommended for
# Locked out of Heaven
# 181                     Bam Bam (feat. Ed Sheeran)
# 19                                      Motivation
# 13                      Leave The Door Open - Live
# 271     The Punjaabban Song (From "Jugjugg Jeeyo")
# 1756                             Deewangi Deewangi
# 1218                          Colombia, Mi Encanto
# 1403                                     Rescue Me
# 1533                                    Bad Habits
# 1435                         ...Baby One More Time
# 1909                                      Sunshine
# Name: track_name, dtype: object
# The following songs were recommended for
# The Lazy Song
# 182                                          Light Switch
# 1323                                               Sucker
# 1175                                              Shivers
# 1298                      There's Nothing Holdin' Me Back
# 19                                             Motivation
# 214                                                Grrrls
# 1397                                             Rude Boy
# 224                                       I Ain't Worried
# 184     Vegas (From the Original Motion Picture Soundt...
# 65                                           Lonely Heart
# Name: track_name, dtype: object
# The following songs were recommended for
# I Still Haven't Found What I'm Looking For
# 824                          Alice's Restaurant Massacree
# 2053                                   Bhar Do Jholi Meri
# 1755                                    Yun Hi Chala Chal
# 2033           I Still Haven't Found What I'm Looking For
# 1367                                              Mirrors
# 1170                                              Run BTS
# 698     The Raven Child (feat. Hansi Kürsch & Jorn Lande)
# 1167                              Cold Heart - PNAU Remix
# 186                       One Right Now (with The Weeknd)
# 1340                                                Sugar
# Name: track_name, dtype: object
# The following songs were recommended for
# Glad You Came
# 1313                               Sit Still, Look Pretty
# 82                                         Stay the Night
# 1954                                     I Don't Know Why
# 1973                                           You for Me
# 65                                           Lonely Heart
# 229                                      SKIN OF MY TEETH
# 1508                                          Superheroes
# 86      Till The End - Jonas Blue & Sam Feldt Present ...
# 1169                             One Kiss (with Dua Lipa)
# 1678                                                   Up
# Name: track_name, dtype: object
# The following songs were recommended for
# Raise Your Glass
# 1169                             One Kiss (with Dua Lipa)
# 187                                                 Woman
# 267     Bhool Bhulaiyaa 2 Title Track (From "Bhool Bhu...
# 1376                                      Don't Start Now
# 1175                                              Shivers
# 64                    Potion (with Dua Lipa & Young Thug)
# 1428                                            The Motto
# 224                                       I Ain't Worried
# 205                                                  Numb
# 1323                                               Sucker
# Name: track_name, dtype: object
# The following songs were recommended for
# Pompeii
# 13                      Leave The Door Open - Live
# 474                  Lean On (feat. MØ & DJ Snake)
# 271     The Punjaabban Song (From "Jugjugg Jeeyo")
# 1533                                    Bad Habits
# 181                     Bam Bam (feat. Ed Sheeran)
# 1218                          Colombia, Mi Encanto
# 1436                              When You're Gone
# 1165                                         Tarot
# 1928                   Damn It Feels Good To Be Me
# 2034                          Locked out of Heaven
# Name: track_name, dtype: object
# The following songs were recommended for
# Forever After All
#
#
# The following songs were recommended for
# couch
# 2144                Backyard Beach
# 537                      Cry To Me
# 566         Music Alone Shall Live
# 546            Simmer Down Quashie
# 557     First Time for a Long Time
# 536        Mighty Redeemer (Pt. 1)
# 763                 Where You Lead
# 554           It Must Be True Love
# 555                     Samfie Man
# 561            Come We Go Moonwalk
# Name: track_name, dtype: object
# The following songs were recommended for
# Forest Whitaker
#
#
# The following songs were recommended for
# Carnaval Del Barrio
#
#
# The following songs were recommended for
# Piragua
#
#
# The following songs were recommended for
# 96,000
#
#
# The following songs were recommended for
# Breathe (feat. Rubén Blades and Doreen Montalvo)
#
#
# The following songs were recommended for
# Kholo Kholo
# 972                    Ballad Of The Sad Young Men - Live
# 985                                   I Remember Clifford
# 986                                                 Älvan
# 1731                                          Kholo Kholo
# 970                                         Danny´s Dream
# 647                                    Master of the Wind
# 977                               In This Wonderful World
# 1053                                  When I Fall In Love
# 698     The Raven Child (feat. Hansi Kürsch & Jorn Lande)
# 975                    I Can't Get Started - Instrumental
# Name: track_name, dtype: object
# The following songs were recommended for
# There's Nothing Holdin' Me Back
# 1175                                              Shivers
# 187                                                 Woman
# 267     Bhool Bhulaiyaa 2 Title Track (From "Bhool Bhu...
# 1323                                               Sucker
# 1516                                        The Lazy Song
# 487                                           Temperature
# 165                                    Late Night Talking
# 1287                             What Makes You Beautiful
# 11                                     That's What I Like
# 64                    Potion (with Dua Lipa & Young Thug)
# Name: track_name, dtype: object
# The following songs were recommended for
# Viva La Vida
# 1600                                Yellow
# 1434                       Blinding Lights
# 160                    MIDDLE OF THE NIGHT
# 1508                           Superheroes
# 1888          This Love (Taylor’s Version)
# 215                              Satellite
# 1872    Lover (Remix) [feat. Shawn Mendes]
# 157                              As It Was
# 1679                    Castle on the Hill
# 206                                So Good
# Name: track_name, dtype: object
# The following songs were recommended for
# All Of You
#
#
# The following songs were recommended for
# Colombia, Mi Encanto
# 13                             Leave The Door Open - Live
# 1445                               Call on Me - Radio Mix
# 670                                          Midnight Sun
# 2149                                      Stuck Like This
# 725                                     Bloodheads United
# 2113                                        My Lighthouse
# 665                                 Welcome To The Circus
# 1241                                                  I2I
# 271            The Punjaabban Song (From "Jugjugg Jeeyo")
# 1578    Sucker for Pain (with Wiz Khalifa, Imagine Dra...
# Name: track_name, dtype: object
# The following songs were recommended for
# 24K Magic
# 187                                                 Woman
# 267     Bhool Bhulaiyaa 2 Title Track (From "Bhool Bhu...
# 64                    Potion (with Dua Lipa & Young Thug)
# 1379                                               My Way
# 205                                                  Numb
# 1376                                      Don't Start Now
# 65                                           Lonely Heart
# 1973                                           You for Me
# 1412                                         Say It Right
# 487                                           Temperature
# Name: track_name, dtype: object
# The following songs were recommended for
# What Else Can I Do?
# 1173      Una Noche en Medellín
# 2024              Tacones Rojos
# 244                  SUPERMODEL
# 2083                  Moonlight
# 1167    Cold Heart - PNAU Remix
# 261              Move Your Body
# 1416                Do It To It
# 1925                    Sunroof
# 178                 First Class
# 1181               Desesperados
# Name: track_name, dtype: object
# The following songs were recommended for
# Waiting On A Miracle
# 1202                  Waiting On A Miracle
# 160                    MIDDLE OF THE NIGHT
# 231                Something in the Orange
# 638                                 Vacant
# 1177                          La Corriente
# 1385                             Boyfriend
# 1872    Lover (Remix) [feat. Shawn Mendes]
# 985                    I Remember Clifford
# 2011                              Bad Liar
# 170              STAY (with Justin Bieber)
# Name: track_name, dtype: object
# The following songs were recommended for
# Surface Pressure
# 1133                     Judge
# 1382              Ready or Not
# 258                      MEAN!
# 2097                       O.O
# 1183          Surface Pressure
# 1320                Youngblood
# 47      Vibe (If I Back It Up)
# 1103           Wahzirinthehood
# 1187       The Family Madrigal
# 1152                    5 Jatt
# Name: track_name, dtype: object
# The following songs were recommended for
# Dos Oruguitas
# 1271    Colors of the Wind - From "Pocahontas" / Sound...
# 1223                   A Dream Is a Wish Your Heart Makes
# 1262    Can You Feel the Love Tonight - End Title/ Fro...
# 995                            When All Was Said and Done
# 2051                           Can't Help Falling in Love
# 1585                                 Feel Good - Stripped
# 1199                                   Part of Your World
# 1027                                                Misty
# 1035       Alone Together - Rudy Van Gelder Remaster 2006
# 1625                                                   ❤️
# Name: track_name, dtype: object
# The following songs were recommended for
# Dil Dhadakne Do
# 2149               Stuck Like This
# 1241                           I2I
# 2113                 My Lighthouse
# 1996               Dil Dhadakne Do
# 325                       Work Out
# 13      Leave The Door Open - Live
# 725              Bloodheads United
# 345            Dance Away The Pain
# 1237    We're All In This Together
# 1843                 Mad at Disney
# Name: track_name, dtype: object

# %% [markdown]
# ```https://towardsdatascience.com/a-one-stop-shop-for-principal-component-analysis-5582fb7e0a9c```
# ```https://www.datacamp.com/tutorial/recommender-systems-python```
